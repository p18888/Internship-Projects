# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
# %matplotlib inline
import warnings
warnings.simplefilter('ignore')

# %%
df = pd.read_csv("/home/pavankumar/data_sci_dec/internship_datasets/Micro Credit Project/Data file.csv",index_col=0)
df
# Out:
#         label       msisdn     aon  daily_decr30  daily_decr90  rental30  \
# 1           0  21408I70789   272.0   3055.050000   3065.150000    220.13
# 2           1  76462I70374   712.0  12122.000000  12124.750000   3691.26
# 3           1  17943I70372   535.0   1398.000000   1398.000000    900.13
# 4           1  55773I70781   241.0     21.228000     21.228000    159.42
# 5           1  03813I82730   947.0    150.619333    150.619333   1098.90
# ...       ...          ...     ...           ...           ...       ...
# 209589      1  22758I85348   404.0    151.872333    151.872333   1089.19
# 209590      1  95583I84455  1075.0     36.936000     36.936000   1728.36
# 209591      1  28556I85350  1013.0  11843.111667  11904.350000   5861.83
# 209592      1  59712I82733  1732.0  12488.228333  12574.370000    411.83
# 209593      1  65061I85339  1581.0   4489.362000   4534.820000    483.92
#
#         rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# ...

# %% [markdown]
# #### Checking datatype and Information of data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 209593 entries, 1 to 209593
# Data columns (total 36 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   label                 209593 non-null  int64
#  1   msisdn                209593 non-null  object
#  2   aon                   209593 non-null  float64
#  3   daily_decr30          209593 non-null  float64
#  4   daily_decr90          209593 non-null  float64
#  5   rental30              209593 non-null  float64
#  6   rental90              209593 non-null  float64
#  7   last_rech_date_ma     209593 non-null  float64
#  8   last_rech_date_da     209593 non-null  float64
#  9   last_rech_amt_ma      209593 non-null  int64
#  10  cnt_ma_rech30         209593 non-null  int64
#  11  fr_ma_rech30          209593 non-null  float64
#  12  sumamnt_ma_rech30     209593 non-null  float64
#  13  medianamnt_ma_rech30  209593 non-null  float64
# ...

# %% [markdown]
# Information tables shows that there is no null values present in the data

# %% [markdown]
# ### Summery Statistic

# %%
df.describe()
# Out:
#                label            aon   daily_decr30   daily_decr90  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean        0.875177    8112.343445    5381.402289    6082.515068
# std         0.330519   75696.082531    9220.623400   10918.812767
# min         0.000000     -48.000000     -93.012667     -93.012667
# 25%         1.000000     246.000000      42.440000      42.692000
# 50%         1.000000     527.000000    1469.175667    1500.000000
# 75%         1.000000     982.000000    7244.000000    7802.790000
# max         1.000000  999860.755168  265926.000000  320630.000000
#
#             rental30       rental90  last_rech_date_ma  last_rech_date_da  \
# count  209593.000000  209593.000000      209593.000000      209593.000000
# mean     2692.581910    3483.406534        3755.847800        3712.202921
# std      4308.586781    5770.461279       53905.892230       53374.833430
# min    -23737.140000  -24720.580000         -29.000000         -29.000000
# ...

# %%
df['pcircle'].value_counts()
# Out:
# UPW    209593
# Name: pcircle, dtype: int64

# %%
df['pdate']=pd.to_datetime(df['pdate'])
df['pdate_year']=df['pdate'].dt.year
df['pdate_month']=df['pdate'].dt.month
df['pdate_day']=df['pdate'].dt.day
df[['pdate_year','pdate_month','pdate_day','pdate']]
df.drop('pdate',axis=1,inplace=True)
df.head()
# Out:
#    label       msisdn    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 1      0  21408I70789  272.0   3055.050000   3065.150000    220.13    260.13
# 2      1  76462I70374  712.0  12122.000000  12124.750000   3691.26   3691.26
# 3      1  17943I70372  535.0   1398.000000   1398.000000    900.13    900.13
# 4      1  55773I70781  241.0     21.228000     21.228000    159.42    159.42
# 5      1  03813I82730  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  cnt_loans90  \
# 1                2.0                0.0              1539  ...          2.0
# 2               20.0                0.0              5787  ...          1.0
# 3                3.0                0.0              1539  ...          1.0
# 4               41.0                0.0               947  ...          2.0
# 5                4.0                0.0              2309  ...          7.0
#
# ...

# %%
df['msisdn'].value_counts()
# Out:
# 04581I85330    7
# 47819I90840    7
# 55809I89238    6
# 29191I82738    6
# 43096I88688    6
#               ..
# 49863I90580    1
# 44656I89235    1
# 24105I90842    1
# 10804I90587    1
# 81096I89236    1
# Name: msisdn, Length: 186243, dtype: int64

# %%
df['msisdn']=df['msisdn'].map(lambda x:int(x.replace("I","")))
df['msisdn']
# Out:
# 1         2140870789
# 2         7646270374
# 3         1794370372
# 4         5577370781
# 5          381382730
#              ...
# 209589    2275885348
# 209590    9558384455
# 209591    2855685350
# 209592    5971282733
# 209593    6506185339
# Name: msisdn, Length: 209593, dtype: int64

# %%
df['pcircle'].value_counts()
# Out:
# UPW    209593
# Name: pcircle, dtype: int64

# %%
df['pcircle']=df['pcircle'].map(lambda x:int(x.replace("UPW","1")))
df['pcircle']
# Out:
# 1         1
# 2         1
# 3         1
# 4         1
# 5         1
#          ..
# 209589    1
# 209590    1
# 209591    1
# 209592    1
# 209593    1
# Name: pcircle, Length: 209593, dtype: int64

# %% [markdown]
# ### Checking and Droping duplicates from the dataset

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (209592, 38)

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True,linewidths=0.1,fmt='0.0%')

# %% [markdown]
# Droping pcircle and pdate_year beacuse there is no uniqueness is present. Entire data set having similar value which not much affect on predecting defaulter or non defaulter.

# %%
df.drop(['pcircle','pdate_year'],axis=1,inplace=True)

# %% [markdown]
# ### Univariate Analysis

# %%
sns.countplot(df['label'])

# %%
print(len(df['daily_decr30'].value_counts()))
print(df['daily_decr30'].skew())
sns.distplot(df['daily_decr30'])
plt.show()
sns.boxplot(df['daily_decr30'])
# Out:
# 147026
# 3.9462190737721934

# %%
plt.hist(df['label'])
plt.show()

# %%
df.boxplot(figsize=(20,10))

# %% [markdown]
# ### Bivariate Analysis
# When we talk about bivariate analysis, it means analyzing 2 variables. Since we know there are numerical and categorical variables, there is a way of analyzing these variables as shown below:
#
# Numerical vs. Numerical
# 1. Scatterplot
# 2. Line plot
# 3. Heatmap for correlation
# 4. Joint plot
#
# Categorical vs. Numerical
# 1. Bar chart
# 2. Violin plot
# 3. Categorical box plot
# 4.Swarm plot
#
# Two Categorical Variables
# 1. Bar chart
# 2. Grouped bar chart
# 3. Point plot

# %%
sns.barplot(x=df['label'],y=df['aon'])

# %% [markdown]
# ### List of Skewness and their distribution Plot

# %%
df.skew()
# Out:
# label                   -2.270245
# msisdn                   0.018133
# aon                     10.392923
# daily_decr30             3.946219
# daily_decr90             4.252553
# rental30                 4.521921
# rental90                 4.437670
# last_rech_date_ma       14.790938
# last_rech_date_da       14.814821
# last_rech_amt_ma         3.781141
# cnt_ma_rech30            3.283838
# fr_ma_rech30            14.772797
# sumamnt_ma_rech30        6.386774
# medianamnt_ma_rech30     3.512314
# medianmarechprebal30    14.779840
# cnt_ma_rech90            3.425244
# fr_ma_rech90             2.285415
# sumamnt_ma_rech90        4.897937
# medianamnt_ma_rech90     3.752696
# medianmarechprebal90    44.880396
# cnt_da_rech30           17.818321
# fr_da_rech30            14.776395
# cnt_da_rech90           27.267213
# fr_da_rech90            28.988013
# cnt_loans30              2.713426
# amnt_loans30             2.975720
# maxamnt_loans30         17.658009
# ...

# %%
skew_lis=[]
for i,j in df.skew().items():
    if j>0.55:
        skew_lis.append(i)
skew_lis=skew_lis[1:]
skew_lis
# Out:
# ['daily_decr30',
#  'daily_decr90',
#  'rental30',
#  'rental90',
#  'last_rech_date_ma',
#  'last_rech_date_da',
#  'last_rech_amt_ma',
#  'cnt_ma_rech30',
#  'fr_ma_rech30',
#  'sumamnt_ma_rech30',
#  'medianamnt_ma_rech30',
#  'medianmarechprebal30',
#  'cnt_ma_rech90',
#  'fr_ma_rech90',
#  'sumamnt_ma_rech90',
#  'medianamnt_ma_rech90',
#  'medianmarechprebal90',
#  'cnt_da_rech30',
#  'fr_da_rech30',
#  'cnt_da_rech90',
#  'fr_da_rech90',
#  'cnt_loans30',
#  'amnt_loans30',
#  'maxamnt_loans30',
#  'medianamnt_loans30',
#  'cnt_loans90',
#  'amnt_loans90',
#  'maxamnt_loans90',
#  'medianamnt_loans90',
#  'payback30',
#  'payback90']

# %%
sns.countplot(df['aon'])
plt.show()
sns.boxplot(df['aon'])
plt.show()
sns.distplot(df['aon'])
plt.show()

# %%
fig, axes = plt.subplots(ncols=2, nrows=16,figsize=(30, 120))

for i, ax in zip(skew_lis, axes.flat):
    sns.distplot(df[i], hist=True, ax=ax)
plt.show()
plt.savefig('distplots_1.pdf')

# %% [markdown]
# ### Scalling Data

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()

# %%
X=df.drop('label',axis=1)
target=df['label']

# %%
ss_x=ss.fit_transform(X)
X=pd.DataFrame(ss_x)

# %% [markdown]
# ### Importing Models

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB,MultinomialNB
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_curve,roc_auc_score

# %% [markdown]
# ### Checking best random state

# %%
# for best random state after standard scaller
best_state=0
accu=0
for i in range(30,250):
    X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    target, test_size=0.30, 
                                                    random_state=i)
    logmodel = LogisticRegression()
    logmodel.fit(X_train,y_train)
    predictions = logmodel.predict(X_test)
    accuracy=accuracy_score(y_test,predictions)
    if accuracy>accu:
        accu=accuracy
        best_state=i
print(f"Final accuracy is{accu} and best random state is {best_state}")
# Out:
# Final accuracy is0.8811826075892999 and best random state is 237

# %% [markdown]
# ### Using Pipeline Models generation

# %%
X_train, X_test, y_train, y_test = train_test_split(X,target, test_size=0.30, 
                                                    random_state=237)

# %%
parameters_deci_c={
 'criterion': ['gini','entropy'],
 'splitter':['best','random'],
 'max_features': ['auto','sqrt'],
 'max_depth':[5],
 'random_state': [237]}

parameters_knn_c={
    'n_neighbors': list(np.arange(5,10)),
    'weights':['uniform','distance'],
#     'algorithm':['auto','ball_tree','kd_tree','brute']
    
}
parameters_svc={
    'kernel': ['linear','poly','rbf','sigmoid'],
    'gamma':['auto','scale'],
    'probability':[True],
#     'max_iter':[500,700,900,1100,1300,1500,1700],
    'max_iter':[500,700],
    
}
parameters_log_reg = {'penalty':['l1', 'l2', 'elasticnet'],
                      'solver':['newton-cg','lbfgs','liblinear','sag','saga']
                     }


parameter_lis=[parameters_log_reg,parameters_knn_c,parameters_svc,parameters_deci_c]
models=[LogisticRegression(),KNeighborsClassifier(),SVC(),DecisionTreeClassifier()]
models_name=['LogisticRegression','KNeighborsClassifier','SVC','DecisionTreeClassifier']
lis_pipes=[]    
best_score=0
best_model_name=''
cv_score=0
for n,model,model_name,parameter in zip(np.arange(1,6),models,models_name,parameter_lis):
    lis_pipes.append(Pipeline([(model_name,GridSearchCV(estimator=model,param_grid=parameter,cv=5,scoring='accuracy'))]))

for model in lis_pipes:
    gsv=model.fit(X_train,y_train)
    pred=gsv[0].best_estimator_.predict(X_test)
    crv=cross_val_score(model,X_train,y_train,cv=2).mean()
    accuracy=accuracy_score(y_test,pred)
    print('Accuracy  Score is : ',accuracy_score(y_test,pred)*100,'%')
    print(confusion_matrix(y_test,pred))
    print(classification_report(y_test,pred))
    print('Best Parameters are : ',gsv[0].best_params_)
    print("\n\n **************Area Under Curve*************")
    y_pred_prob=gsv[0].predict_proba(X_test)[:,1]
    false_positive_rate,true_positive_rate,thresholds=roc_curve(y_test,y_pred_prob)
    plt.plot([0,1],[0,1],'k--')
    plt.plot(false_positive_rate,true_positive_rate)
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('AUC-ROC Curve')
    plt.show()
    print(f'\nCross Validation Score is : {crv}\nModel name is {gsv}\n==============================================================================')
    if accuracy>best_score:
        best_score=accuracy
        best_model_name=[]
        best_model_name.append(gsv[0])
        
print(f"Best model name is :  {best_model_name[0]}")
# Out:
# Accuracy  Score is :  88.14688762365215 %
# [[  317  7289]
#  [  164 55108]]
#               precision    recall  f1-score   support
#
#            0       0.66      0.04      0.08      7606
#            1       0.88      1.00      0.94     55272
#
#     accuracy                           0.88     62878
#    macro avg       0.77      0.52      0.51     62878
# weighted avg       0.86      0.88      0.83     62878
#
# Best Parameters are :  {'penalty': 'l2', 'solver': 'saga'}
#
#
#  **************Area Under Curve*************
# Cross Validation Score is : 0.8753902149760759
# Model name is Pipeline(steps=[('LogisticRegression',
#                  GridSearchCV(cv=5, estimator=LogisticRegression(),
#                               param_grid={'penalty': ['l1', 'l2', 'elasticnet'],
#                                           'solver': ['newton-cg', 'lbfgs',
#                                                      'liblinear', 'sag',
# ...

# %% [markdown]
# ### Saving the best model

# %%
knn = KNeighborsClassifier(n_neighbors= 9, weights= 'uniform')
knn.fit(X_train,y_train)

# %% [markdown]
# ## Conclusion : From all model best model is KNeighborsClassifier with 88.61 % accuracy

# %%
import pickle
file_name='micro_credit_defaulter.pkl'
pickle.dump(knn,open(file_name,'wb'))
